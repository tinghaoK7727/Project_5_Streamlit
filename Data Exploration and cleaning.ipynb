# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r'/Users/tinghaokao/Desktop/Group 2_ Heart attack possibility/heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.shape
# Out:
# (303, 14)

# %%
df.hist(figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'cp'}>,
#         <AxesSubplot:title={'center':'trestbps'}>],
#        [<AxesSubplot:title={'center':'chol'}>,
#         <AxesSubplot:title={'center':'fbs'}>,
#         <AxesSubplot:title={'center':'restecg'}>,
#         <AxesSubplot:title={'center':'thalach'}>],
#        [<AxesSubplot:title={'center':'exang'}>,
#         <AxesSubplot:title={'center':'oldpeak'}>,
#         <AxesSubplot:title={'center':'slope'}>,
#         <AxesSubplot:title={'center':'ca'}>],
#        [<AxesSubplot:title={'center':'thal'}>,
#         <AxesSubplot:title={'center':'target'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,9))
heat_map = sns.heatmap(df.corr(),annot=True)
heat_map
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# grouped by sex
df.groupby('sex').mean()
# Out:
#            age        cp    trestbps        chol      fbs   restecg  \
# sex
# 0    55.677083  1.041667  133.083333  261.302083  0.12500  0.572917
# 1    53.758454  0.932367  130.946860  239.289855  0.15942  0.507246
#
#         thalach     exang   oldpeak     slope        ca      thal    target
# sex
# 0    151.125000  0.229167  0.876042  1.427083  0.552083  2.125000  0.750000
# 1    148.961353  0.371981  1.115459  1.386473  0.811594  2.400966  0.449275

# %%
# Correlation test between sex and target

from scipy.stats.stats import pearsonr

v_sex = df['sex']
v_target = df['target']

pearsonr(v_sex, v_target)

# P-value is less than 5%, negative correlation between the two variables not rejected
# Out:
# (-0.2809365755017672, 6.678692115314112e-07)

# %%
# grouped by chest pain type
df.groupby('cp').mean()
# Out:
#           age       sex    trestbps        chol       fbs   restecg  \
# cp
# 0   55.692308  0.727273  132.020979  250.132867  0.125874  0.475524
# 1   51.360000  0.640000  128.400000  244.780000  0.100000  0.620000
# 2   53.517241  0.597701  130.379310  243.172414  0.195402  0.597701
# 3   55.869565  0.826087  140.869565  237.130435  0.217391  0.391304
#
#        thalach     exang   oldpeak     slope        ca      thal    target
# cp
# 0   140.538462  0.559441  1.383217  1.258741  0.965035  2.447552  0.272727
# 1   162.420000  0.080000  0.316000  1.680000  0.420000  2.140000  0.820000
# 2   155.609195  0.126437  0.797701  1.505747  0.586207  2.206897  0.793103
# 3   155.956522  0.173913  1.391304  1.260870  0.478261  2.260870  0.695652

# %%
# Correlation test between chest pain and target

from scipy.stats.stats import pearsonr

v_cp = df['cp']
v_target = df['target']

pearsonr(v_cp, v_target)

# P-value is less than 5%, correlation between the two variables not rejected
# Out:
# (0.43379826150689327, 2.469712108923143e-15)

# %%
# grouped by fasting blood sugar
df.groupby('fbs').mean()
# Out:
#            age       sex        cp    trestbps        chol   restecg  \
# fbs
# 0    53.906977  0.674419  0.926357  130.325581  245.976744  0.546512
# 1    57.000000  0.733333  1.200000  139.066667  247.911111  0.422222
#
#         thalach     exang   oldpeak     slope        ca      thal    target
# fbs
# 0    149.728682  0.321705  1.036822  1.414729  0.670543  2.321705  0.550388
# 1    149.177778  0.355556  1.055556  1.311111  1.066667  2.266667  0.511111

# %%
# Correlation test between fasting blood sugar and target

from scipy.stats.stats import pearsonr

v_fbs = df['fbs']
v_target = df['target']

pearsonr(v_fbs, v_target)

# P-value is bigger than 5%, correlation between the two variables rejected
# Out:
# (-0.02804576027271293, 0.6267775474340695)

# %%
# grouped by restecg
df.groupby('restecg').mean()
# Out:
#                age       sex        cp    trestbps        chol       fbs  \
# restecg
# 0        55.687075  0.700680  0.904762  134.027211  255.142857  0.176871
# 1        52.914474  0.677632  1.039474  129.065789  237.269737  0.125000
# 2        61.000000  0.250000  0.500000  140.500000  261.750000  0.000000
#
#             thalach     exang   oldpeak     slope        ca      thal  \
# restecg
# 0        147.904762  0.367347  1.159184  1.319728  0.816327  2.312925
# 1        151.960526  0.282895  0.879605  1.493421  0.638158  2.322368
# 2        125.750000  0.500000  2.725000  0.750000  1.000000  2.000000
#
#            target
# restecg
# 0        0.462585
# 1        0.631579
# 2        0.250000

# %%
# Correlation test bewteen restecg and taregt

from scipy.stats.stats import pearsonr

v_restecg = df['restecg']
v_target = df['target']

pearsonr(v_restecg, v_target)

# P-value is less than 5%, correlation between the two variables not rejected
# Out:
# (0.137229502873773, 0.016839897060127305)

# %%
# grouped by exang
df.groupby('exang').mean()
# Out:
#              age       sex        cp    trestbps        chol       fbs  \
# exang
# 0      53.754902  0.637255  1.250000  130.799020  243.848039  0.142157
# 1      55.626263  0.777778  0.383838  133.323232  251.242424  0.161616
#
#         restecg     thalach   oldpeak     slope        ca      thal    target
# exang
# 0      0.553922  155.681373  0.806863  1.509804  0.647059  2.225490  0.696078
# 1      0.474747  137.212121  1.519192  1.171717  0.898990  2.494949  0.232323

# %%
# Correlation test bewteen exang and taregt

from scipy.stats.stats import pearsonr

v_exang = df['exang']
v_target = df['target']

pearsonr(v_exang, v_target)

# P-value is less than 5%, negative correlation between the two variables not rejected
# Out:
# (-0.4367570833533034, 1.5208138383313768e-15)

# %%
# grouped by slope
df.groupby('slope').mean()
# Out:
#              age       sex        cp    trestbps        chol       fbs  \
# slope
# 0      55.380952  0.761905  1.000000  139.476190  237.666667  0.285714
# 1      56.100000  0.678571  0.792857  132.100000  249.121429  0.135714
# 2      52.507042  0.676056  1.133803  129.992958  244.718310  0.140845
#
#         restecg     thalach     exang   oldpeak        ca      thal    target
# slope
# 0      0.476190  144.904762  0.428571  2.714286  0.571429  2.333333  0.428571
# 1      0.478571  139.292857  0.457143  1.428571  0.885714  2.392857  0.350000
# 2      0.584507  160.556338  0.183099  0.408451  0.598592  2.232394  0.753521

# %%
# Correlation test bewteen slope and taregt

from scipy.stats.stats import pearsonr

v_slope = df['slope']
v_target = df['target']

pearsonr(v_slope, v_target)

# P-value is less than 5%, correlation between the two variables not rejected
# Out:
# (0.34587707824172426, 6.101610619565504e-10)

# %%
# grouped by vesself
df.groupby('ca').mean()
# Out:
#           age       sex        cp    trestbps        chol       fbs   restecg  \
# ca
# 0   51.645714  0.634286  1.137143  130.800000  242.697143  0.114286  0.571429
# 1   57.476923  0.769231  0.876923  129.630769  248.123077  0.138462  0.476923
# 2   59.789474  0.657895  0.500000  135.710526  254.447368  0.263158  0.447368
# 3   59.900000  0.800000  0.550000  136.900000  265.450000  0.250000  0.400000
# 4   45.800000  1.000000  1.400000  134.200000  208.000000  0.200000  0.800000
#
#        thalach     exang   oldpeak     slope      thal    target
# ca
# 0   154.988571  0.251429  0.836571  1.434286  2.222857  0.742857
# 1   141.092308  0.461538  1.013846  1.400000  2.430769  0.323077
# 2   146.210526  0.447368  1.707895  1.342105  2.421053  0.184211
# 3   134.550000  0.350000  1.865000  1.150000  2.500000  0.150000
# 4   160.400000  0.200000  0.100000  1.600000  2.400000  0.800000

# %%
# Correlation test bewteen vesself and taregt

from scipy.stats.stats import pearsonr

v_ca = df['ca']
v_target = df['target']

pearsonr(v_ca, v_target)

# P-value is less than 5%, negative correlation between the two variables not rejected
# Out:
# (-0.39172399235125216, 1.4915387381122498e-12)

# %%
# grouped by thal
df.groupby('thal').mean()
# Out:
#             age       sex        cp    trestbps        chol       fbs  \
# thal
# 0     52.500000  0.500000  1.000000  128.000000  210.000000  0.500000
# 1     56.666667  0.944444  0.666667  136.944444  227.000000  0.277778
# 2     53.246988  0.524096  1.216867  129.385542  246.048193  0.120482
# 3     55.632479  0.871795  0.658120  134.042735  250.153846  0.162393
#
#        restecg     thalach     exang   oldpeak     slope        ca    target
# thal
# 0     0.500000  135.500000  0.500000  0.500000  1.500000  0.000000  0.500000
# 1     0.500000  135.111111  0.444444  1.522222  0.944444  1.000000  0.333333
# 2     0.542169  155.771084  0.186747  0.682530  1.566265  0.524096  0.783133
# 3     0.512821  143.435897  0.504274  1.481197  1.230769  0.991453  0.239316

# %%
# Correlation test bewteen thal and taregt

from scipy.stats.stats import pearsonr

v_thal = df['thal']
v_target = df['target']

pearsonr(v_thal, v_target)

# P-value is less than 5%, negative correlation between the two variables not rejected
# Out:
# (-0.34402926803831024, 7.624879909571867e-10)

# %%
# grouped by oldpeak
df.groupby('oldpeak').mean().head()
# Out:
#                age       sex        cp    trestbps        chol       fbs  \
# oldpeak
# 0.0      50.757576  0.646465  1.070707  129.010101  241.404040  0.121212
# 0.1      55.285714  0.857143  0.714286  122.857143  222.857143  0.428571
# 0.2      56.500000  0.500000  1.166667  134.416667  254.000000  0.166667
# 0.3      56.000000  0.333333  1.000000  116.000000  242.000000  0.000000
# 0.4      58.333333  0.777778  0.888889  130.333333  241.888889  0.000000
#
#           restecg     thalach     exang     slope        ca      thal  \
# oldpeak
# 0.0      0.555556  162.202020  0.191919  1.838384  0.535354  2.131313
# 0.1      0.428571  145.857143  0.285714  1.571429  1.428571  2.428571
# 0.2      0.666667  148.750000  0.333333  1.416667  0.416667  2.500000
# 0.3      1.000000  144.000000  0.000000  1.666667  1.000000  2.333333
# 0.4      0.555556  151.555556  0.111111  1.333333  0.777778  2.333333
#
#            target
# oldpeak
# 0.0      0.747475
# 0.1      0.571429
# ...

# %%
# Correlation test bewteen maxheart and taregt

from scipy.stats.stats import pearsonr

v_oldpeak = df['oldpeak']
v_target = df['target']

pearsonr(v_oldpeak, v_target)

# P-value is less than 5%, negative correlation between the two variables not rejected
# Out:
# (-0.43069600168736877, 4.085346391354625e-15)

# %%
# grouped by age
df.groupby('age').mean().head()
# Out:
#       sex        cp  trestbps        chol  fbs  restecg  thalach     exang  \
# age
# 29   1.00  1.000000     130.0  204.000000  0.0     0.00    202.0  0.000000
# 34   0.50  2.000000     118.0  196.000000  0.0     0.50    183.0  0.000000
# 35   0.75  0.250000     126.5  213.750000  0.0     0.75    160.5  0.500000
# 37   0.50  2.000000     125.0  232.500000  0.0     1.00    178.5  0.000000
# 38   1.00  2.333333     132.0  193.666667  0.0     1.00    176.0  0.333333
#
#       oldpeak     slope        ca      thal    target
# age
# 29   0.000000  2.000000  0.000000  2.000000  1.000000
# 34   0.350000  2.000000  0.000000  2.000000  1.000000
# 35   0.750000  1.750000  0.000000  2.500000  0.500000
# 37   1.750000  1.000000  0.000000  2.000000  1.000000
# 38   1.266667  1.666667  2.666667  2.333333  0.666667

# %%
# Correlation test bewteen age and target

from scipy.stats.stats import pearsonr

v_age = df['age']
v_target = df['target']

pearsonr(v_age, v_target)

# P-value is less than 5%, negative correlation between the two variables not rejected
# Out:
# (-0.22543871587483716, 7.524801303442636e-05)

# %%
# grouped by thalach
df.groupby('thalach').mean().head()
# Out:
#           age  sex   cp  trestbps   chol  fbs  restecg  exang  oldpeak  slope  \
# thalach
# 71       67.0  1.0  0.0     120.0  237.0  0.0      1.0    0.0      1.0    1.0
# 88       57.0  1.0  0.0     152.0  274.0  0.0      1.0    1.0      1.2    1.0
# 90       59.0  1.0  0.0     164.0  176.0  1.0      0.0    0.0      1.0    1.0
# 95       53.0  1.0  0.0     123.0  282.0  0.0      1.0    1.0      2.0    1.0
# 96       62.0  0.5  1.0     120.0  212.0  0.5      0.5    0.5      1.1    1.0
#
#           ca  thal  target
# thalach
# 71       0.0   2.0     0.0
# 88       1.0   3.0     0.0
# 90       2.0   1.0     0.0
# 95       2.0   3.0     0.0
# 96       0.5   2.0     0.5

# %%
# Correlation test bewteen age and target

from scipy.stats.stats import pearsonr

v_thalach = df['thalach']  # max heart beat
v_target = df['target'] # having heart attack

pearsonr(v_thalach, v_target)

# P-value is less than 5%, correlation between the two variables not rejected
# Out:
# (0.4217409338106745, 1.6973376386561237e-14)

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
pd.plotting.scatter_matrix(df, figsize=(15, 12))
# Out:
# array([[<AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='sex', ylabel='age'>,
#         <AxesSubplot:xlabel='cp', ylabel='age'>,
#         <AxesSubplot:xlabel='trestbps', ylabel='age'>,
#         <AxesSubplot:xlabel='chol', ylabel='age'>,
#         <AxesSubplot:xlabel='fbs', ylabel='age'>,
#         <AxesSubplot:xlabel='restecg', ylabel='age'>,
#         <AxesSubplot:xlabel='thalach', ylabel='age'>,
#         <AxesSubplot:xlabel='exang', ylabel='age'>,
#         <AxesSubplot:xlabel='oldpeak', ylabel='age'>,
#         <AxesSubplot:xlabel='slope', ylabel='age'>,
#         <AxesSubplot:xlabel='ca', ylabel='age'>,
#         <AxesSubplot:xlabel='thal', ylabel='age'>,
#         <AxesSubplot:xlabel='target', ylabel='age'>],
#        [<AxesSubplot:xlabel='age', ylabel='sex'>,
#         <AxesSubplot:xlabel='sex', ylabel='sex'>,
#         <AxesSubplot:xlabel='cp', ylabel='sex'>,
#         <AxesSubplot:xlabel='trestbps', ylabel='sex'>,
# ...
